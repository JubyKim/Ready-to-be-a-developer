# %%
n = int(input())

candiList = []
for i in range(111,1000):
    if 0 not in i :
        candiList.append(i)
print(candiList)



for i in range(n):
    num, strk, ball = list(map(int, input().split()))
    numSet = set([str(num)[0],str(num)[1],str(num)[2]])
    
#     for candi in candiList:
#         if
# Out:
# 1
# ...

# %% [markdown]
# ## print("a" in "amy")

# %%
numSet
# Out:
# {'1', '2', '3'}

# %%
if len(set([str(i)[0],str(i)[1],str(i)[2]])) == 3 :
        if '0' not in set([str(i)[0],str(i)[1],str(i)[2]]):
            candiList.append(set([str(i)[0],str(i)[1],str(i)[2]]))
