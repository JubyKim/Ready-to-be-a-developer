# %%
from collections import deque
import copy


dx = [0, 0, 1, -1]
dy = [1, -1, 0, 0]

def bfs():
    tmp_graph, queue = deque()
    for i in range(n): #2인 칸의 좌표 넣기.
        for j in range(m):
            if tmp_graph[i][j] == 2:
                queue.append((i, j))
                
    while queue:
        x, y = queue.popleft()
        
        for i in range(4): #상 하 우 좌
            nx = x + dx[i]
            ny = y + dy[i]

            if nx < 0 or nx >= n or ny < 0 or ny >= m:
                continue
                
            if tmp_graph[nx][ny] == 0:
                tmp_graph[nx][ny] = 2
                queue.append((nx, ny))

    global answer
    cnt = 0

    for i in range(n):
        cnt += tmp_graph[i].count(0)

    answer = max(answer, cnt)

def makeWall(cnt #백트래킹
    if cnt == 3:
        bfs()
        return

    for i in range(n):
        for j in range(m):
            if graph[i][j] == 0:
                graph[i][j] = 1
                makeWall(cnt+1)
                graph[i][j] = 0 #비워놔
                
                
n, m = map(int, input().split())
graph = []

for i in range(n):
    graph.append(list(map(int, input().split())))

answer = 0
makeWall(0)
print(answer)
